# %%
import sys, os
# !git clone "https://github.com/vvshankar78/DeepLearning.git"
my_path = '/content/DeepLearning/Extensive VisionAI-EVA6/11_YOLO/OpenCV_Yolo'
os.chdir(my_path)
# Out:
# Cloning into 'DeepLearning'...
# remote: Enumerating objects: 2083, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 2083 (delta 3), reused 18 (delta 3), pack-reused 2065
# Receiving objects: 100% (2083/2083), 409.87 MiB | 43.54 MiB/s, done.
# Resolving deltas: 100% (577/577), done.
# Checking out files: 100% (1276/1276), done.

# %%
import requests, zipfile, io
import cv2
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
import main
from main import RunYolo
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-2cec78188c6b> in <module>()
#       4 import matplotlib.pyplot as plt
#       5 import urllib.request
# ----> 6 import main
#       7 from main import RunYolo
#
# /content/DeepLearning/Extensive VisionAI-EVA6/11_YOLO/OpenCV_Yolo/main.py in <module>()
#       3
#       4 # Load Yolo
# ----> 5 net = cv2.dnn.readNet("yolov3.weights", "yolov3.cfg")
#       6 classes = []
#       7 with open("coco.names", "r") as f:
#
# error: OpenCV(4.1.2) /io/opencv/modules/dnn/src/darknet/darknet_importer.cpp:214: error: (-212:Parsing error) Failed to parse NetParameter file: yolov3.weights in function 'readNetFromDarknet'

# %%
url = "https://pjreddie.com/media/files/yolov3.weights"
path = my_path + "/yolov3.weights"
# urllib.request.urlretrieve(url, path)

# %%
yolo = RunYolo(url, my_path)

# %%
yolo.download_weight()

# %%
net = cv2.dnn.readNet("yolov3.weights", "yolov3.cfg")

# %%
classes = []
with open("coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
colors = np.random.uniform(0, 255, size=(len(classes), 3))

# %%
from PIL import Image

im_path  = 'input/room_ser.jpg'
im = Image.open(im_path)

img = cv2.imread(im_path)
img = cv2.resize(img, None, fx=0.4, fy=0.4)
height, width, channels = img.shape

# %%
# cv2.imshow("image",img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Detecting objects
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
net.setInput(blob)
outs = net.forward(output_layers)

# %%
# cv2.imshow("0",blob[0][0])
# cv2.imshow("1",blob[0][1])
# cv2.imshow("2",blob[0][2])

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# Showing informations on the screen
class_ids = []
confidences = []
boxes = []
for out in outs:
    for detection in out:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if confidence > 0.5:
            # Object detected
            center_x = int(detection[0] * width)
            center_y = int(detection[1] * height)
            w = int(detection[2] * width)
            h = int(detection[3] * height)
            # Rectangle coordinates
            x = int(center_x - w / 2)
            y = int(center_y - h / 2)
            boxes.append([x, y, w, h])
            confidences.append(float(confidence))
            class_ids.append(class_id)

# %%
indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)

# %%
class_labels = []
font = cv2.FONT_HERSHEY_PLAIN
for i in range(len(boxes)):
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        color = colors[i]
        class_labels.append(label)
        print(label)
        cv2.rectangle(img, (x, y), (x + w, y + h), color, 2)
        cv2.putText(img, label, (x, y + 30), font, 3, color, 3)
# cv2.imshow("Image", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# print()
# Out:
# laptop
# chair
# tvmonitor
# book

# %%
exif = im.getexif()
creation_time = exif.get(36867)
print('time of creation of image is - ',creation_time)
print('classes in the image are - ', list(set(class_labels)))
print('image name is - ',str.split(im_path,'/')[-1])
# plt.imshow(img);
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# cv2.imshow("image",img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
