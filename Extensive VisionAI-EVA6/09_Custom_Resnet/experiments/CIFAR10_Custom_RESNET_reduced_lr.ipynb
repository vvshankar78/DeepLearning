# %%
# !pip install -U albumentations
# !pip install ttach
# !pip install torch-lr-finder
# Out:
# Requirement already up-to-date: albumentations in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied, skipping upgrade: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (4.5.2.54)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.7/dist-packages (from albumentations) (3.13)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.16.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (0.16.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from albumentations) (1.4.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (2.5.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (2.4.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (7.1.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (1.1.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (3.2.2)
# Requirement already satisfied, skipping upgrade: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.0->scikit-image>=0.16.1->albumentations) (4.4.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (1.3.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (1.15.0)
# Requirement already satisfied: ttach in /usr/local/lib/python3.7/dist-packages (0.0.3)
# Requirement already satisfied: torch-lr-finder in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (20.9)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (4.41.1)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (1.9.0+cu102)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (1.19.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (3.2.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torch-lr-finder) (2.4.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=0.4.1->torch-lr-finder) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->torch-lr-finder) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->torch-lr-finder) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->torch-lr-finder) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->torch-lr-finder) (1.15.0)

# %%
# !git clone "https://github.com/jacobgil/pytorch-grad-cam.git"
# !git clone "https://github.com/vvshankar78/DeepLearning.git"
# Out:
# fatal: destination path 'pytorch-grad-cam' already exists and is not an empty directory.
# fatal: destination path 'DeepLearning' already exists and is not an empty directory.

# %%
import sys, os

# /content/DeepLearning/Extensive VisionAI-EVA6/
my_path = 'DeepLearning/Extensive VisionAI-EVA6/09_Custom_Resnet'
sys.path.append(my_path)
# os.listdir(my_path)

my_path_cam = '/content/pytorch-grad-cam'
sys.path.append(my_path_cam)

import main

# %%
data,train_loader, test_loader = main.get_data()
# Out:
# Model Parameters:
# { 'batch_size_cpu': 512,
#   'batch_size_cuda': 512,
#   'dropout_value': 0.0,
#   'epochs': 24,
#   'num_workers': 4,
#   'peak': 5,
#   'seed': 1}
# 24
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
main.show_data(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model= main.get_model()
main.get_lr_finder(model, train_loader)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 3.51E-03

# %%
model= main.get_model()
main.get_ocp_plot(train_loader, model, max_lr=3.5e-2) # max lr is considered 10 time suggested lr from lr finder

# %%
history = main.run_model(model, train_loader, test_loader, max_lr=3.5e-2)
# Out:
#   0%|          | 0/98 [00:00<?, ?it/s]
# EPOCH: 1
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss=1.337118148803711 Batch_id=97 Accuracy=43.44: 100%|██████████| 98/98 [00:31<00:00,  3.12it/s]
# length of Average loss 98, length of Average accuracy 98
#
# learning rate 0.008133742331288343
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 5775/10000 (57.75%)
#
# EPOCH: 2
# Loss=0.8498694896697998 Batch_id=97 Accuracy=63.23: 100%|██████████| 98/98 [00:31<00:00,  3.12it/s]
# length of Average loss 196, length of Average accuracy 196
#
# learning rate 0.014867484662576688
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0027, Accuracy: 6021/10000 (60.21%)
#
# EPOCH: 3
# Loss=0.7352935075759888 Batch_id=97 Accuracy=72.71: 100%|██████████| 98/98 [00:31<00:00,  3.12it/s]
# length of Average loss 294, length of Average accuracy 294
#
# learning rate 0.021601226993865033
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0017, Accuracy: 7286/10000 (72.86%)
#
# EPOCH: 4
# Loss=0.696890652179718 Batch_id=97 Accuracy=76.28: 100%|██████████| 98/98 [00:31<00:00,  3.11it/s]
# length of Average loss 392, length of Average accuracy 392
#
# learning rate 0.028334969325153378
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0013, Accuracy: 7914/10000 (79.14%)
#
# EPOCH: 5
# Loss=0.4958767294883728 Batch_id=97 Accuracy=81.84: 100%|██████████| 98/98 [00:31<00:00,  3.11it/s]
# length of Average loss 490, length of Average accuracy 490
#
# learning rate 0.03498120308270677
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0017, Accuracy: 7624/10000 (76.24%)
#
# EPOCH: 6
# Loss=0.37657350301742554 Batch_id=97 Accuracy=85.79: 100%|██████████| 98/98 [00:31<00:00,  3.14it/s]
# length of Average loss 588, length of Average accuracy 588
#
# learning rate 0.033139105187969926
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0014, Accuracy: 7909/10000 (79.09%)
#
# EPOCH: 7
# Loss=0.33405008912086487 Batch_id=97 Accuracy=89.54: 100%|██████████| 98/98 [00:31<00:00,  3.11it/s]
# length of Average loss 686, length of Average accuracy 686
#
# learning rate 0.031297007293233085
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0018, Accuracy: 7523/10000 (75.23%)
#
# EPOCH: 8
# Loss=0.2547394335269928 Batch_id=97 Accuracy=92.64: 100%|██████████| 98/98 [00:31<00:00,  3.13it/s]
# length of Average loss 784, length of Average accuracy 784
#
# learning rate 0.029454909398496244
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0011, Accuracy: 8386/10000 (83.86%)
#
# EPOCH: 9
# Loss=0.17678137123584747 Batch_id=97 Accuracy=94.23: 100%|██████████| 98/98 [00:31<00:00,  3.08it/s]
# length of Average loss 882, length of Average accuracy 882
#
# learning rate 0.027612811503759403
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0011, Accuracy: 8337/10000 (83.37%)
#
# EPOCH: 10
# Loss=0.1406574249267578 Batch_id=97 Accuracy=95.82: 100%|██████████| 98/98 [00:31<00:00,  3.13it/s]
# length of Average loss 980, length of Average accuracy 980
#
# learning rate 0.02577071360902256
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0011, Accuracy: 8427/10000 (84.27%)
#
# EPOCH: 11
# Loss=0.09481275826692581 Batch_id=97 Accuracy=97.08: 100%|██████████| 98/98 [00:31<00:00,  3.10it/s]
# length of Average loss 1078, length of Average accuracy 1078
#
# learning rate 0.023928615714285714
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 83 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 85 %
# Accuracy of  deer : 72 %
# Accuracy of   dog : 75 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0010, Accuracy: 8596/10000 (85.96%)
#
# EPOCH: 12
# Loss=0.0556635856628418 Batch_id=97 Accuracy=97.86: 100%|██████████| 98/98 [00:31<00:00,  3.07it/s]
# length of Average loss 1176, length of Average accuracy 1176
#
# learning rate 0.022086517819548873
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 85 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 80 %
# Accuracy of   cat : 80 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 100 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 85 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0010, Accuracy: 8665/10000 (86.65%)
#
# EPOCH: 13
# Loss=0.06401340663433075 Batch_id=97 Accuracy=98.08: 100%|██████████| 98/98 [00:31<00:00,  3.10it/s]
# length of Average loss 1274, length of Average accuracy 1274
#
# learning rate 0.020244419924812032
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 88 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 80 %
# Accuracy of   cat : 83 %
# Accuracy of  deer : 85 %
# Accuracy of   dog : 63 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 57 %
#
# Test set: Average loss: 0.0010, Accuracy: 8715/10000 (87.15%)
#
# EPOCH: 14
# Loss=0.05715783312916756 Batch_id=97 Accuracy=98.75: 100%|██████████| 98/98 [00:31<00:00,  3.08it/s]
# length of Average loss 1372, length of Average accuracy 1372
#
# learning rate 0.01840232203007519
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 80 %
# Accuracy of   car : 80 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 70 %
# Accuracy of  deer : 87 %
# Accuracy of   dog : 90 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 83 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 75 %
#
# Test set: Average loss: 0.0010, Accuracy: 8763/10000 (87.63%)
#
# EPOCH: 15
# Loss=0.04859011620283127 Batch_id=97 Accuracy=98.99: 100%|██████████| 98/98 [00:31<00:00,  3.10it/s]
# length of Average loss 1470, length of Average accuracy 1470
#
# learning rate 0.01656022413533835
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 62 %
# Accuracy of   car : 90 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 100 %
# Accuracy of  deer : 60 %
# Accuracy of   dog : 100 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 90 %
# Accuracy of  ship : 88 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8764/10000 (87.64%)
#
# EPOCH: 16
# Loss=0.01327010989189148 Batch_id=97 Accuracy=99.23: 100%|██████████| 98/98 [00:31<00:00,  3.08it/s]
# length of Average loss 1568, length of Average accuracy 1568
#
# learning rate 0.014718126240601509
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 88 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 66 %
# Accuracy of   cat : 90 %
# Accuracy of  deer : 88 %
# Accuracy of   dog : 88 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 80 %
# Accuracy of  ship : 91 %
# Accuracy of truck : 75 %
#
# Test set: Average loss: 0.0009, Accuracy: 8807/10000 (88.07%)
#
# EPOCH: 17
# Loss=0.021232467144727707 Batch_id=97 Accuracy=99.39: 100%|██████████| 98/98 [00:32<00:00,  3.05it/s]
# length of Average loss 1666, length of Average accuracy 1666
#
# learning rate 0.012876028345864664
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 80 %
# Accuracy of   car : 88 %
# Accuracy of  bird : 57 %
# Accuracy of   cat : 80 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 88 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 85 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0010, Accuracy: 8826/10000 (88.26%)
#
# EPOCH: 18
# Loss=0.019524017348885536 Batch_id=97 Accuracy=99.55: 100%|██████████| 98/98 [00:31<00:00,  3.10it/s]
# length of Average loss 1764, length of Average accuracy 1764
#
# learning rate 0.01103393045112782
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 83 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 92 %
# Accuracy of   cat : 77 %
# Accuracy of  deer : 85 %
# Accuracy of   dog : 71 %
# Accuracy of  frog : 88 %
# Accuracy of horse : 87 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8818/10000 (88.18%)
#
# EPOCH: 19
# Loss=0.0072185141034424305 Batch_id=97 Accuracy=99.65: 100%|██████████| 98/98 [00:31<00:00,  3.09it/s]
# length of Average loss 1862, length of Average accuracy 1862
#
# learning rate 0.009191832556390979
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 88 %
# Accuracy of   cat : 85 %
# Accuracy of  deer : 75 %
# Accuracy of   dog : 75 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 90 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8837/10000 (88.37%)
#
# EPOCH: 20
# Loss=0.014149177819490433 Batch_id=97 Accuracy=99.72: 100%|██████████| 98/98 [00:32<00:00,  3.05it/s]
# length of Average loss 1960, length of Average accuracy 1960
#
# learning rate 0.007349734661654138
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 80 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 88 %
# Accuracy of   cat : 81 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 100 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 75 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8893/10000 (88.93%)
#
# EPOCH: 21
# Loss=0.007571663241833448 Batch_id=97 Accuracy=99.73: 100%|██████████| 98/98 [00:31<00:00,  3.07it/s]
# length of Average loss 2058, length of Average accuracy 2058
#
# learning rate 0.005507636766917297
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 83 %
# Accuracy of  bird : 76 %
# Accuracy of   cat : 90 %
# Accuracy of  deer : 87 %
# Accuracy of   dog : 75 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 75 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8892/10000 (88.92%)
#
# EPOCH: 22
# Loss=0.008190802298486233 Batch_id=97 Accuracy=99.84: 100%|██████████| 98/98 [00:32<00:00,  3.05it/s]
# length of Average loss 2156, length of Average accuracy 2156
#
# learning rate 0.0036655388721804558
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 60 %
# Accuracy of  deer : 92 %
# Accuracy of   dog : 88 %
# Accuracy of  frog : 90 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8918/10000 (89.18%)
#
# EPOCH: 23
# Loss=0.005743621848523617 Batch_id=97 Accuracy=99.84: 100%|██████████| 98/98 [00:31<00:00,  3.07it/s]
# length of Average loss 2254, length of Average accuracy 2254
#
# learning rate 0.0018234409774436147
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 83 %
# Accuracy of  deer : 80 %
# Accuracy of   dog : 85 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 70 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0008, Accuracy: 8920/10000 (89.20%)
#
# EPOCH: 24
# Loss=0.004675049334764481 Batch_id=97 Accuracy=99.86: 100%|██████████| 98/98 [00:32<00:00,  3.05it/s]
# length of Average loss 2352, length of Average accuracy 2352
#
# learning rate -1.8656917293226327e-05
# Accuracy of plane : 75 %
# Accuracy of   car : 83 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 85 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 83 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0008, Accuracy: 8917/10000 (89.17%)

# %%
main.get_training_curves(history)

# %%
main.get_show_misclassified(model, test_loader, num_of_images=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
