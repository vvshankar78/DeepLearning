# %%
# !pip install -U albumentations
# !pip install ttach
# !pip install torch-lr-finder
# Out:
# Requirement already up-to-date: albumentations in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from albumentations) (1.4.1)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.7/dist-packages (from albumentations) (3.13)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.16.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (0.16.2)
# Requirement already satisfied, skipping upgrade: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (4.5.2.54)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (2.5.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (2.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (3.2.2)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (7.1.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (1.1.1)
# Requirement already satisfied, skipping upgrade: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.0->scikit-image>=0.16.1->albumentations) (4.4.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (1.3.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (0.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (1.15.0)
# Requirement already satisfied: ttach in /usr/local/lib/python3.7/dist-packages (0.0.3)
# Requirement already satisfied: torch-lr-finder in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (20.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (3.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (4.41.1)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from torch-lr-finder) (1.9.0+cu102)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torch-lr-finder) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->torch-lr-finder) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->torch-lr-finder) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->torch-lr-finder) (2.8.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=0.4.1->torch-lr-finder) (3.7.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib->torch-lr-finder) (1.15.0)

# %%
# !git clone "https://github.com/jacobgil/pytorch-grad-cam.git"
# !git clone "https://github.com/vvshankar78/DeepLearning.git"
# Out:
# fatal: destination path 'pytorch-grad-cam' already exists and is not an empty directory.
# fatal: destination path 'DeepLearning' already exists and is not an empty directory.

# %%
import sys, os

# /content/DeepLearning/Extensive VisionAI-EVA6/
my_path = 'DeepLearning/Extensive VisionAI-EVA6/09_Custom_Resnet'
sys.path.append(my_path)
# os.listdir(my_path)

my_path_cam = '/content/pytorch-grad-cam'
sys.path.append(my_path_cam)

import main

# %%
data,train_loader, test_loader = main.get_data()
# Out:
# Model Parameters:
# { 'batch_size_cpu': 512,
#   'batch_size_cuda': 512,
#   'dropout_value': 0.0,
#   'epochs': 24,
#   'num_workers': 4,
#   'peak': 5,
#   'seed': 1}
# 24
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
main.show_data(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model= main.get_model()
main.get_lr_finder(model, train_loader)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.52E-03

# %%
model= main.get_model()
main.get_ocp_plot(train_loader, model, max_lr=2.3e-2) # max lr is considered 10 time suggested lr from lr finder

# %%
history = main.run_model(model, train_loader, test_loader, max_lr=2.3e-2)
# Out:
#   0%|          | 0/98 [00:00<?, ?it/s]
# EPOCH: 1
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss=1.340137243270874 Batch_id=97 Accuracy=41.27: 100%|██████████| 98/98 [00:31<00:00,  3.10it/s]
# length of Average loss 98, length of Average accuracy 98
#
# learning rate 0.005345030674846625
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0025, Accuracy: 5642/10000 (56.42%)
#
# EPOCH: 2
# Loss=0.9277631044387817 Batch_id=97 Accuracy=64.38: 100%|██████████| 98/98 [00:31<00:00,  3.13it/s]
# length of Average loss 196, length of Average accuracy 196
#
# learning rate 0.009770061349693252
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0019, Accuracy: 6708/10000 (67.08%)
#
# EPOCH: 3
# Loss=0.619678795337677 Batch_id=97 Accuracy=72.71: 100%|██████████| 98/98 [00:31<00:00,  3.12it/s]
# length of Average loss 294, length of Average accuracy 294
#
# learning rate 0.014195092024539877
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0019, Accuracy: 7026/10000 (70.26%)
#
# EPOCH: 4
# Loss=0.6758677959442139 Batch_id=97 Accuracy=78.19: 100%|██████████| 98/98 [00:31<00:00,  3.15it/s]
# length of Average loss 392, length of Average accuracy 392
#
# learning rate 0.018620122699386503
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0016, Accuracy: 7489/10000 (74.89%)
#
# EPOCH: 5
# Loss=0.5971297025680542 Batch_id=97 Accuracy=80.96: 100%|██████████| 98/98 [00:31<00:00,  3.10it/s]
# length of Average loss 490, length of Average accuracy 490
#
# learning rate 0.022987647740064447
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0031, Accuracy: 6591/10000 (65.91%)
#
# EPOCH: 6
# Loss=0.42390450835227966 Batch_id=97 Accuracy=87.00: 100%|██████████| 98/98 [00:31<00:00,  3.11it/s]
# length of Average loss 588, length of Average accuracy 588
#
# learning rate 0.021777126266380235
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0014, Accuracy: 7875/10000 (78.75%)
#
# EPOCH: 7
# Loss=0.34595224261283875 Batch_id=97 Accuracy=89.54: 100%|██████████| 98/98 [00:31<00:00,  3.14it/s]
# length of Average loss 686, length of Average accuracy 686
#
# learning rate 0.020566604792696026
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0012, Accuracy: 8158/10000 (81.58%)
#
# EPOCH: 8
# Loss=0.22661547362804413 Batch_id=97 Accuracy=92.81: 100%|██████████| 98/98 [00:30<00:00,  3.17it/s]
# length of Average loss 784, length of Average accuracy 784
#
# learning rate 0.019356083319011813
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0011, Accuracy: 8402/10000 (84.02%)
#
# EPOCH: 9
# Loss=0.1687803417444229 Batch_id=97 Accuracy=94.55: 100%|██████████| 98/98 [00:30<00:00,  3.18it/s]
# length of Average loss 882, length of Average accuracy 882
#
# learning rate 0.018145561845327604
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0014, Accuracy: 8121/10000 (81.21%)
#
# EPOCH: 10
# Loss=0.10845533013343811 Batch_id=97 Accuracy=95.99: 100%|██████████| 98/98 [00:31<00:00,  3.15it/s]
# length of Average loss 980, length of Average accuracy 980
#
# learning rate 0.016935040371643395
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 90 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 50 %
# Accuracy of   cat : 100 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 60 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 71 %
# Accuracy of  ship : 85 %
# Accuracy of truck : 90 %
#
# Test set: Average loss: 0.0010, Accuracy: 8507/10000 (85.07%)
#
# EPOCH: 11
# Loss=0.08475054800510406 Batch_id=97 Accuracy=97.11: 100%|██████████| 98/98 [00:30<00:00,  3.18it/s]
# length of Average loss 1078, length of Average accuracy 1078
#
# learning rate 0.015724518897959183
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 87 %
# Accuracy of   cat : 50 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 88 %
# Accuracy of  frog : 80 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 90 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0010, Accuracy: 8590/10000 (85.90%)
#
# EPOCH: 12
# Loss=0.04062496870756149 Batch_id=97 Accuracy=97.82: 100%|██████████| 98/98 [00:31<00:00,  3.16it/s]
# length of Average loss 1176, length of Average accuracy 1176
#
# learning rate 0.014513997424274972
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0011, Accuracy: 8474/10000 (84.74%)
#
# EPOCH: 13
# Loss=0.06380568444728851 Batch_id=97 Accuracy=98.31: 100%|██████████| 98/98 [00:31<00:00,  3.15it/s]
# length of Average loss 1274, length of Average accuracy 1274
#
# learning rate 0.013303475950590763
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 90 %
# Accuracy of   car : 90 %
# Accuracy of  bird : 72 %
# Accuracy of   cat : 57 %
# Accuracy of  deer : 81 %
# Accuracy of   dog : 100 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 77 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8707/10000 (87.07%)
#
# EPOCH: 14
# Loss=0.03138814494013786 Batch_id=97 Accuracy=98.83: 100%|██████████| 98/98 [00:31<00:00,  3.15it/s]
# length of Average loss 1372, length of Average accuracy 1372
#
# learning rate 0.012092954476906552
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 63 %
# Accuracy of  deer : 80 %
# Accuracy of   dog : 100 %
# Accuracy of  frog : 91 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 88 %
#
# Test set: Average loss: 0.0009, Accuracy: 8673/10000 (86.73%)
#
# EPOCH: 15
# Loss=0.027730992063879967 Batch_id=97 Accuracy=99.12: 100%|██████████| 98/98 [00:31<00:00,  3.15it/s]
# length of Average loss 1470, length of Average accuracy 1470
#
# learning rate 0.010882433003222341
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 90 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 71 %
# Accuracy of   cat : 80 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 71 %
# Accuracy of  frog : 66 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 85 %
# Accuracy of truck : 92 %
#
# Test set: Average loss: 0.0010, Accuracy: 8726/10000 (87.26%)
#
# EPOCH: 16
# Loss=0.026953766122460365 Batch_id=97 Accuracy=99.32: 100%|██████████| 98/98 [00:31<00:00,  3.15it/s]
# length of Average loss 1568, length of Average accuracy 1568
#
# learning rate 0.009671911529538132
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 87 %
# Accuracy of  bird : 85 %
# Accuracy of   cat : 90 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 85 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 88 %
# Accuracy of  ship : 87 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0010, Accuracy: 8731/10000 (87.31%)
#
# EPOCH: 17
# Loss=0.02846214920282364 Batch_id=97 Accuracy=99.49: 100%|██████████| 98/98 [00:31<00:00,  3.11it/s]
# length of Average loss 1666, length of Average accuracy 1666
#
# learning rate 0.00846139005585392
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 63 %
# Accuracy of   cat : 87 %
# Accuracy of  deer : 71 %
# Accuracy of   dog : 88 %
# Accuracy of  frog : 77 %
# Accuracy of horse : 80 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8799/10000 (87.99%)
#
# EPOCH: 18
# Loss=0.016142306849360466 Batch_id=97 Accuracy=99.62: 100%|██████████| 98/98 [00:31<00:00,  3.12it/s]
# length of Average loss 1764, length of Average accuracy 1764
#
# learning rate 0.007250868582169709
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 90 %
# Accuracy of   car : 77 %
# Accuracy of  bird : 83 %
# Accuracy of   cat : 100 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 87 %
# Accuracy of  frog : 85 %
# Accuracy of horse : 90 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8745/10000 (87.45%)
#
# EPOCH: 19
# Loss=0.015385597944259644 Batch_id=97 Accuracy=99.75: 100%|██████████| 98/98 [00:32<00:00,  3.00it/s]
# length of Average loss 1862, length of Average accuracy 1862
#
# learning rate 0.0060403471084855
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 85 %
# Accuracy of   car : 66 %
# Accuracy of  bird : 90 %
# Accuracy of   cat : 78 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 75 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 88 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8822/10000 (88.22%)
#
# EPOCH: 20
# Loss=0.010451181791722775 Batch_id=97 Accuracy=99.79: 100%|██████████| 98/98 [00:31<00:00,  3.13it/s]
# length of Average loss 1960, length of Average accuracy 1960
#
# learning rate 0.004829825634801287
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 80 %
# Accuracy of   car : 85 %
# Accuracy of  bird : 83 %
# Accuracy of   cat : 83 %
# Accuracy of  deer : 81 %
# Accuracy of   dog : 50 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 75 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 75 %
#
# Test set: Average loss: 0.0009, Accuracy: 8824/10000 (88.24%)
#
# EPOCH: 21
# Loss=0.0037710112519562244 Batch_id=97 Accuracy=99.82: 100%|██████████| 98/98 [00:31<00:00,  3.14it/s]
# length of Average loss 2058, length of Average accuracy 2058
#
# learning rate 0.0036193041611170783
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 83 %
# Accuracy of   car : 90 %
# Accuracy of  bird : 62 %
# Accuracy of   cat : 85 %
# Accuracy of  deer : 66 %
# Accuracy of   dog : 75 %
# Accuracy of  frog : 91 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 88 %
#
# Test set: Average loss: 0.0009, Accuracy: 8798/10000 (87.98%)
#
# EPOCH: 22
# Loss=0.0026216518599539995 Batch_id=97 Accuracy=99.86: 100%|██████████| 98/98 [00:31<00:00,  3.13it/s]
# length of Average loss 2156, length of Average accuracy 2156
#
# learning rate 0.0024087826874328658
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 88 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 60 %
# Accuracy of  deer : 88 %
# Accuracy of   dog : 57 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 83 %
# Accuracy of truck : 87 %
#
# Test set: Average loss: 0.0009, Accuracy: 8816/10000 (88.16%)
#
# EPOCH: 23
# Loss=0.016490522772073746 Batch_id=97 Accuracy=99.87: 100%|██████████| 98/98 [00:31<00:00,  3.14it/s]
# length of Average loss 2254, length of Average accuracy 2254
#
# learning rate 0.0011982612137486567
#   0%|          | 0/98 [00:00<?, ?it/s]
# Accuracy of plane : 100 %
# Accuracy of   car : 83 %
# Accuracy of  bird : 91 %
# Accuracy of   cat : 66 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 50 %
# Accuracy of  frog : 90 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 88 %
#
# Test set: Average loss: 0.0009, Accuracy: 8839/10000 (88.39%)
#
# EPOCH: 24
# Loss=0.01595115475356579 Batch_id=97 Accuracy=99.86: 100%|██████████| 98/98 [00:31<00:00,  3.16it/s]
# length of Average loss 2352, length of Average accuracy 2352
#
# learning rate -1.2260259935552298e-05
# Accuracy of plane : 100 %
# Accuracy of   car : 90 %
# Accuracy of  bird : 100 %
# Accuracy of   cat : 66 %
# Accuracy of  deer : 100 %
# Accuracy of   dog : 92 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %
#
# Test set: Average loss: 0.0009, Accuracy: 8836/10000 (88.36%)

# %%
main.get_training_curves(history)

# %%
main.get_show_misclassified(model, test_loader, num_of_images=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
