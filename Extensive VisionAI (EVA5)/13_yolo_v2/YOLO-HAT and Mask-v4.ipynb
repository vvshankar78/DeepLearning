# %%
# load Google Driver
from google.colab import drive
import sys, os
drive.mount('/content/drive')

my_path = '/content/drive/My Drive/Computer Vision/Extensive VisionAI (EVA5)/13_yolo_v2'
sys.path.append(my_path)
os.listdir(my_path)
# Out:
# Mounted at /content/drive
# ['YoloV3',
#  'ubdivisions=1',
#  'train.py',
#  'results.json',
#  'models.py',
#  'test.py',
#  'ting',
#  'vim.exe.stackdump',
#  'YOLO-Walle.ipynb',
#  'detect.py',
#  'results.png',
#  'YOLO-HAT and Mask.ipynb',
#  'YOLO-HAT and Mask-v2.ipynb',
#  'train_out',
#  'test_batch0.png',
#  'results.txt',
#  'train_out (1) - images',
#  'utils',
#  'annotation_tool',
#  '__pycache__',
#  'cfg',
#  'runs',
#  '.git',
#  'YOLO-HAT and Mask-v3.ipynb',
#  'README.md']

# %%
cd 'drive/My Drive/Computer Vision/Extensive VisionAI (EVA5)/13_yolo_v2/YoloV3'
# Out:
# /content/drive/My Drive/Computer Vision/Extensive VisionAI (EVA5)/13_yolo_v2/YoloV3

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git

# %%
# !ls
# Out:
#  annotation_tool   results.json      train_out
#  cfg		   results.png	    'train_out (1) - images'
#  data		   results.txt	     train.py
#  detect.py	   runs		    'ubdivisions=1'
#  models.py	   test_batch0.png   utils
#  __pycache__	   test.py	     vim.exe.stackdump
#  README.md	   ting		     weights

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !python train.py --data data/YoloV3_Dataset/train.data --batch 16 --cache --cfg cfg/yolov3-hat.cfg --epochs 200 --weights='weights/last.pt'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-hat.cfg', data='data/YoloV3_Dataset/train.data', device='', epochs=200, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-25 13:16:49.044799: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3032 found, 129 missing, 38 empty, 0 duplicate, for 3199 images): 100% 3199/3199 [00:02<00:00, 1132.30it/s]
# Caching images (1.8GB): 100% 3199/3199 [00:26<00:00, 122.41it/s]
# ...

# %%
# !python train.py --data data/YoloV3_Dataset/train.data --batch 16 --cache --cfg cfg/yolov3-hat.cfg --epochs 200 --weights='weights/last.pt'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-hat.cfg', data='data/YoloV3_Dataset/train.data', device='', epochs=200, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-10-26 08:44:33.782693: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3032 found, 129 missing, 38 empty, 0 duplicate, for 3199 images): 100% 3199/3199 [23:44<00:00,  2.25it/s]
# Caching images (1.8GB): 100% 3199/3199 [25:23<00:00,  2.10it/s]
# ...

# %%
# !python train.py --data data/YoloV3_Dataset/train.data --batch 16 --cache --cfg cfg/yolov3-hat.cfg --epochs 300 --weights='weights/last.pt'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-hat.cfg', data='data/YoloV3_Dataset/train.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-10-26 16:31:36.793846: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3032 found, 129 missing, 38 empty, 0 duplicate, for 3199 images): 100% 3199/3199 [00:03<00:00, 941.93it/s]
# Caching images (1.8GB): 100% 3199/3199 [00:27<00:00, 115.97it/s]
# ...

# %%
# !python train.py --data data/YoloV3_Dataset/train.data --batch 16 --cache --cfg cfg/yolov3-hat.cfg --epochs 300 --weights='weights/last.pt'

# %%
# !python detect.py --conf-thres 0.3 --output train_out #--source 'data/samples'# --weights='weights/last.pt'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-hat.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/YoloV3_Dataset/classes.txt', output='train_out', save_txt=False, source='data/samples', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/27 data/samples/1.jpg.jpeg: 512x320 1 hardhats, Done. (0.034s)
# image 2/27 data/samples/2.jpg.jpeg: 384x512 1 masks, Done. (0.030s)
# image 3/27 data/samples/3.jpg.jpeg: 512x256 1 hardhats, 1 masks, Done. (0.024s)
# image 4/27 data/samples/4.jpg.jpeg: 448x512 4 hardhats, Done. (0.035s)
# image 5/27 data/samples/WhatsApp Image 2020-10-25 at 01.53.44 (1).jpeg: 512x384 1 hardhats, Done. (0.032s)
# image 6/27 data/samples/WhatsApp Image 2020-10-25 at 01.53.44 (2).jpeg: 512x320 1 hardhats, 1 bootss, Done. (0.029s)
# ...

# %%
Image(filename='train_out/1.jpg.jpeg', width=600)
